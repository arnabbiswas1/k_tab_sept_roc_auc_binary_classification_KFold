# %%
import sys
import logging
import math
import re

import glob
import os
import sys

import pandas as pd
import numpy as np

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

sys.path.insert(0, "/opt/vssexclude/personal/kaggle/k_tab_aug")

# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
import src.config.constants as constants
import src.munging as process_data
import src.viz as viz
import src.common as common
import src.config.tsfresh_config as tsfresh_config

# %%
logger = logging.getLogger()

# %% [markdown]
# ### List

# %%
file_names = ["mixed_1_set","symmetry_large_std_quantile_set","acf_pacf_set","cwt_coeff_set","change_quantile_set","fft_real_set","fft_imag_set","fft_abs_set","fft_angle_set","fft_agg_set","liner_agg_linear_set","mixed_2_set","mixed_3_set","mixed_4_set"]

# %%
file_names
# Out:
# ['mixed_1_set',
#  'symmetry_large_std_quantile_set',
#  'acf_pacf_set',
#  'cwt_coeff_set',
#  'change_quantile_set',
#  'fft_real_set',
#  'fft_imag_set',
#  'fft_abs_set',
#  'fft_angle_set',
#  'fft_agg_set',
#  'liner_agg_linear_set',
#  'mixed_2_set',
#  'mixed_3_set',
#  'mixed_4_set']

# %%
no_of_columns = 0
for name in file_names:
    df = pd.read_parquet(f"{constants.FEATURES_DATA_DIR}/cast/{name}_cast.parquet")
    print(f"Shape of {name}: {df.shape[1]}")
    no_of_columns = no_of_columns + df.shape[1]
no_of_columns
# Out:
# Shape of mixed_1_set: 44
# Shape of symmetry_large_std_quantile_set: 47
# Shape of acf_pacf_set: 23
# Shape of cwt_coeff_set: 60
# Shape of change_quantile_set: 60
# Shape of fft_real_set: 100
# Shape of fft_imag_set: 100
# Shape of fft_abs_set: 100
# Shape of fft_angle_set: 100
# Shape of fft_agg_set: 4
# Shape of liner_agg_linear_set: 53
# Shape of mixed_2_set: 24
# Shape of mixed_3_set: 30
# Shape of mixed_4_set: 42
# 787

# %%
def select_features(df, features_to_drop):
    logger.info(f"Shape of the features {df.shape}")
    df = df.drop(features_to_drop, axis=1)
    logger.info(f"Shape of the features after dropping {df.shape}")
    return df

def load_data(name, features_to_drop):
    df = pd.read_parquet(f"{constants.FEATURES_DATA_DIR}/cast/{name}_cast.parquet")
    print(f"Shape of {name} before droipping {df.shape}")
    df = select_features(df, features_to_drop)
    print(f"Shape of {name} after droipping {df.shape}")
    return df

# %%
name = "mixed_1_set"
features_to_drop = ['loan__has_duplicate_min', 'loan__length', 'loan__sample_entropy']
df_mixed_1_set = load_data(name, features_to_drop)

name = "symmetry_large_std_quantile_set"
features_to_drop = features_to_drop = [
    "loan__symmetry_looking__r_0.0",
    "loan__symmetry_looking__r_0.1",
    "loan__symmetry_looking__r_0.15000000000000002",
    "loan__symmetry_looking__r_0.2",
    "loan__symmetry_looking__r_0.25",
    "loan__symmetry_looking__r_0.30000000000000004",
    "loan__symmetry_looking__r_0.35000000000000003",
    "loan__symmetry_looking__r_0.4",
    "loan__symmetry_looking__r_0.45",
    "loan__symmetry_looking__r_0.5",
    "loan__symmetry_looking__r_0.55",
    "loan__symmetry_looking__r_0.6000000000000001",
    "loan__symmetry_looking__r_0.65",
    "loan__symmetry_looking__r_0.7000000000000001",
    "loan__symmetry_looking__r_0.75",
    "loan__symmetry_looking__r_0.8",
    "loan__symmetry_looking__r_0.8500000000000001",
    "loan__symmetry_looking__r_0.9",
    "loan__symmetry_looking__r_0.9500000000000001",
    "loan__large_standard_deviation__r_0.05",
    "loan__large_standard_deviation__r_0.1",
    "loan__large_standard_deviation__r_0.15000000000000002",
    "loan__large_standard_deviation__r_0.30000000000000004",
    "loan__large_standard_deviation__r_0.35000000000000003",
    "loan__large_standard_deviation__r_0.4",
    "loan__large_standard_deviation__r_0.45",
    "loan__large_standard_deviation__r_0.5",
    "loan__large_standard_deviation__r_0.55",
    "loan__large_standard_deviation__r_0.6000000000000001",
    "loan__large_standard_deviation__r_0.65",
    "loan__large_standard_deviation__r_0.7000000000000001",
    "loan__large_standard_deviation__r_0.75",
    "loan__large_standard_deviation__r_0.8",
    "loan__large_standard_deviation__r_0.8500000000000001",
    "loan__large_standard_deviation__r_0.9",
    "loan__large_standard_deviation__r_0.9500000000000001",
]
df_sym = load_data(name, features_to_drop)

name = "acf_pacf_set"
features_to_drop = ["loan__partial_autocorrelation__lag_0"]
df_acf_pacf_set = load_data(name, features_to_drop)

name = "cwt_coeff_set"
features_to_drop = []
df_cwt_coeff_set = load_data(name, features_to_drop)

name = "change_quantile_set"
features_to_drop = []
df_change_quantile_set = load_data(name, features_to_drop)

name = "liner_agg_linear_set"
features_to_drop = [
    "loan__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_max",
    "loan__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_min",
    "loan__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_mean",
    "loan__agg_linear_trend__attr_stderr__chunk_len_50__f_agg_var",
]
df_liner_agg_linear_set = load_data(name, features_to_drop)

name = "mixed_2_set"
features_to_drop = [
    "loan__count_above__t_0",
    "loan__query_similarity_count__query_None__threshold_00",
    "loan__matrix_profile__feature_min__threshold_098",
    "loan__matrix_profile__feature_max__threshold_098",
    "loan__matrix_profile__feature_mean__threshold_098",
    "loan__matrix_profile__feature_median__threshold_098",
    "loan__matrix_profile__feature_25__threshold_098",
    "loan__matrix_profile__feature_75__threshold_098",
]
df_mixed_2_set = load_data(name, features_to_drop)

name = "mixed_3_set"
features_to_drop = []
df_mixed_3_set = load_data(name, features_to_drop)

name = "mixed_4_set"
features_to_drop = [
        "loan__value_count__value_minus1",
        "loan__range_count__max_0__min_10000000000000",
        "loan__range_count__max_10000000000000__min_0",
        "loan__number_crossing_m__m_minus1",
        "loan__ratio_beyond_r_sigma__r_5",
        "loan__ratio_beyond_r_sigma__r_6",
        "loan__ratio_beyond_r_sigma__r_7",
        "loan__ratio_beyond_r_sigma__r_10",
]
df_mixed_4_set = load_data(name, features_to_drop)

name = "fft_real_set"
features_to_drop = [
    "loan__fft_coefficient__attr_real__coeff_51",
    "loan__fft_coefficient__attr_real__coeff_52",
    "loan__fft_coefficient__attr_real__coeff_53",
    "loan__fft_coefficient__attr_real__coeff_54",
    "loan__fft_coefficient__attr_real__coeff_55",
    "loan__fft_coefficient__attr_real__coeff_56",
    "loan__fft_coefficient__attr_real__coeff_57",
    "loan__fft_coefficient__attr_real__coeff_58",
    "loan__fft_coefficient__attr_real__coeff_59",
    "loan__fft_coefficient__attr_real__coeff_60",
    "loan__fft_coefficient__attr_real__coeff_61",
    "loan__fft_coefficient__attr_real__coeff_62",
    "loan__fft_coefficient__attr_real__coeff_63",
    "loan__fft_coefficient__attr_real__coeff_64",
    "loan__fft_coefficient__attr_real__coeff_65",
    "loan__fft_coefficient__attr_real__coeff_66",
    "loan__fft_coefficient__attr_real__coeff_67",
    "loan__fft_coefficient__attr_real__coeff_68",
    "loan__fft_coefficient__attr_real__coeff_69",
    "loan__fft_coefficient__attr_real__coeff_70",
    "loan__fft_coefficient__attr_real__coeff_71",
    "loan__fft_coefficient__attr_real__coeff_72",
    "loan__fft_coefficient__attr_real__coeff_73",
    "loan__fft_coefficient__attr_real__coeff_74",
    "loan__fft_coefficient__attr_real__coeff_75",
    "loan__fft_coefficient__attr_real__coeff_76",
    "loan__fft_coefficient__attr_real__coeff_77",
    "loan__fft_coefficient__attr_real__coeff_78",
    "loan__fft_coefficient__attr_real__coeff_79",
    "loan__fft_coefficient__attr_real__coeff_80",
    "loan__fft_coefficient__attr_real__coeff_81",
    "loan__fft_coefficient__attr_real__coeff_82",
    "loan__fft_coefficient__attr_real__coeff_83",
    "loan__fft_coefficient__attr_real__coeff_84",
    "loan__fft_coefficient__attr_real__coeff_85",
    "loan__fft_coefficient__attr_real__coeff_86",
    "loan__fft_coefficient__attr_real__coeff_87",
    "loan__fft_coefficient__attr_real__coeff_88",
    "loan__fft_coefficient__attr_real__coeff_89",
    "loan__fft_coefficient__attr_real__coeff_90",
    "loan__fft_coefficient__attr_real__coeff_91",
    "loan__fft_coefficient__attr_real__coeff_92",
    "loan__fft_coefficient__attr_real__coeff_93",
    "loan__fft_coefficient__attr_real__coeff_94",
    "loan__fft_coefficient__attr_real__coeff_95",
    "loan__fft_coefficient__attr_real__coeff_96",
    "loan__fft_coefficient__attr_real__coeff_97",
    "loan__fft_coefficient__attr_real__coeff_98",
    "loan__fft_coefficient__attr_real__coeff_99",
]
df_fft_real_set = load_data(name, features_to_drop)

name = "fft_imag_set"
features_to_drop = [
    "loan__fft_coefficient__attr_imag__coeff_0",
    "loan__fft_coefficient__attr_imag__coeff_50",
    "loan__fft_coefficient__attr_imag__coeff_51",
    "loan__fft_coefficient__attr_imag__coeff_52",
    "loan__fft_coefficient__attr_imag__coeff_53",
    "loan__fft_coefficient__attr_imag__coeff_54",
    "loan__fft_coefficient__attr_imag__coeff_55",
    "loan__fft_coefficient__attr_imag__coeff_56",
    "loan__fft_coefficient__attr_imag__coeff_57",
    "loan__fft_coefficient__attr_imag__coeff_58",
    "loan__fft_coefficient__attr_imag__coeff_59",
    "loan__fft_coefficient__attr_imag__coeff_60",
    "loan__fft_coefficient__attr_imag__coeff_61",
    "loan__fft_coefficient__attr_imag__coeff_62",
    "loan__fft_coefficient__attr_imag__coeff_63",
    "loan__fft_coefficient__attr_imag__coeff_64",
    "loan__fft_coefficient__attr_imag__coeff_65",
    "loan__fft_coefficient__attr_imag__coeff_66",
    "loan__fft_coefficient__attr_imag__coeff_67",
    "loan__fft_coefficient__attr_imag__coeff_68",
    "loan__fft_coefficient__attr_imag__coeff_69",
    "loan__fft_coefficient__attr_imag__coeff_70",
    "loan__fft_coefficient__attr_imag__coeff_71",
    "loan__fft_coefficient__attr_imag__coeff_72",
    "loan__fft_coefficient__attr_imag__coeff_73",
    "loan__fft_coefficient__attr_imag__coeff_74",
    "loan__fft_coefficient__attr_imag__coeff_75",
    "loan__fft_coefficient__attr_imag__coeff_76",
    "loan__fft_coefficient__attr_imag__coeff_77",
    "loan__fft_coefficient__attr_imag__coeff_78",
    "loan__fft_coefficient__attr_imag__coeff_79",
    "loan__fft_coefficient__attr_imag__coeff_80",
    "loan__fft_coefficient__attr_imag__coeff_81",
    "loan__fft_coefficient__attr_imag__coeff_82",
    "loan__fft_coefficient__attr_imag__coeff_83",
    "loan__fft_coefficient__attr_imag__coeff_84",
    "loan__fft_coefficient__attr_imag__coeff_85",
    "loan__fft_coefficient__attr_imag__coeff_86",
    "loan__fft_coefficient__attr_imag__coeff_87",
    "loan__fft_coefficient__attr_imag__coeff_88",
    "loan__fft_coefficient__attr_imag__coeff_89",
    "loan__fft_coefficient__attr_imag__coeff_90",
    "loan__fft_coefficient__attr_imag__coeff_91",
    "loan__fft_coefficient__attr_imag__coeff_92",
    "loan__fft_coefficient__attr_imag__coeff_93",
    "loan__fft_coefficient__attr_imag__coeff_94",
    "loan__fft_coefficient__attr_imag__coeff_95",
    "loan__fft_coefficient__attr_imag__coeff_96",
    "loan__fft_coefficient__attr_imag__coeff_97",
    "loan__fft_coefficient__attr_imag__coeff_98",
    "loan__fft_coefficient__attr_imag__coeff_99",
]
df_fft_imag_set = load_data(name, features_to_drop)

name = "fft_abs_set"
features_to_drop = [
    "loan__fft_coefficient__attr_abs__coeff_51",
    "loan__fft_coefficient__attr_abs__coeff_52",
    "loan__fft_coefficient__attr_abs__coeff_53",
    "loan__fft_coefficient__attr_abs__coeff_54",
    "loan__fft_coefficient__attr_abs__coeff_55",
    "loan__fft_coefficient__attr_abs__coeff_56",
    "loan__fft_coefficient__attr_abs__coeff_57",
    "loan__fft_coefficient__attr_abs__coeff_58",
    "loan__fft_coefficient__attr_abs__coeff_59",
    "loan__fft_coefficient__attr_abs__coeff_60",
    "loan__fft_coefficient__attr_abs__coeff_61",
    "loan__fft_coefficient__attr_abs__coeff_62",
    "loan__fft_coefficient__attr_abs__coeff_63",
    "loan__fft_coefficient__attr_abs__coeff_64",
    "loan__fft_coefficient__attr_abs__coeff_65",
    "loan__fft_coefficient__attr_abs__coeff_66",
    "loan__fft_coefficient__attr_abs__coeff_67",
    "loan__fft_coefficient__attr_abs__coeff_68",
    "loan__fft_coefficient__attr_abs__coeff_69",
    "loan__fft_coefficient__attr_abs__coeff_70",
    "loan__fft_coefficient__attr_abs__coeff_71",
    "loan__fft_coefficient__attr_abs__coeff_72",
    "loan__fft_coefficient__attr_abs__coeff_73",
    "loan__fft_coefficient__attr_abs__coeff_74",
    "loan__fft_coefficient__attr_abs__coeff_75",
    "loan__fft_coefficient__attr_abs__coeff_76",
    "loan__fft_coefficient__attr_abs__coeff_77",
    "loan__fft_coefficient__attr_abs__coeff_78",
    "loan__fft_coefficient__attr_abs__coeff_79",
    "loan__fft_coefficient__attr_abs__coeff_80",
    "loan__fft_coefficient__attr_abs__coeff_81",
    "loan__fft_coefficient__attr_abs__coeff_82",
    "loan__fft_coefficient__attr_abs__coeff_83",
    "loan__fft_coefficient__attr_abs__coeff_84",
    "loan__fft_coefficient__attr_abs__coeff_85",
    "loan__fft_coefficient__attr_abs__coeff_86",
    "loan__fft_coefficient__attr_abs__coeff_87",
    "loan__fft_coefficient__attr_abs__coeff_88",
    "loan__fft_coefficient__attr_abs__coeff_89",
    "loan__fft_coefficient__attr_abs__coeff_90",
    "loan__fft_coefficient__attr_abs__coeff_91",
    "loan__fft_coefficient__attr_abs__coeff_92",
    "loan__fft_coefficient__attr_abs__coeff_93",
    "loan__fft_coefficient__attr_abs__coeff_94",
    "loan__fft_coefficient__attr_abs__coeff_95",
    "loan__fft_coefficient__attr_abs__coeff_96",
    "loan__fft_coefficient__attr_abs__coeff_97",
    "loan__fft_coefficient__attr_abs__coeff_98",
    "loan__fft_coefficient__attr_abs__coeff_99",
]
df_fft_abs_set = load_data(name, features_to_drop)

name = "fft_angle_set"
features_to_drop = [
    "loan__fft_coefficient__attr_angle__coeff_0",
    "loan__fft_coefficient__attr_angle__coeff_51",
    "loan__fft_coefficient__attr_angle__coeff_52",
    "loan__fft_coefficient__attr_angle__coeff_53",
    "loan__fft_coefficient__attr_angle__coeff_54",
    "loan__fft_coefficient__attr_angle__coeff_55",
    "loan__fft_coefficient__attr_angle__coeff_56",
    "loan__fft_coefficient__attr_angle__coeff_57",
    "loan__fft_coefficient__attr_angle__coeff_58",
    "loan__fft_coefficient__attr_angle__coeff_59",
    "loan__fft_coefficient__attr_angle__coeff_60",
    "loan__fft_coefficient__attr_angle__coeff_61",
    "loan__fft_coefficient__attr_angle__coeff_62",
    "loan__fft_coefficient__attr_angle__coeff_63",
    "loan__fft_coefficient__attr_angle__coeff_64",
    "loan__fft_coefficient__attr_angle__coeff_65",
    "loan__fft_coefficient__attr_angle__coeff_66",
    "loan__fft_coefficient__attr_angle__coeff_67",
    "loan__fft_coefficient__attr_angle__coeff_68",
    "loan__fft_coefficient__attr_angle__coeff_69",
    "loan__fft_coefficient__attr_angle__coeff_70",
    "loan__fft_coefficient__attr_angle__coeff_71",
    "loan__fft_coefficient__attr_angle__coeff_72",
    "loan__fft_coefficient__attr_angle__coeff_73",
    "loan__fft_coefficient__attr_angle__coeff_74",
    "loan__fft_coefficient__attr_angle__coeff_75",
    "loan__fft_coefficient__attr_angle__coeff_76",
    "loan__fft_coefficient__attr_angle__coeff_77",
    "loan__fft_coefficient__attr_angle__coeff_78",
    "loan__fft_coefficient__attr_angle__coeff_79",
    "loan__fft_coefficient__attr_angle__coeff_80",
    "loan__fft_coefficient__attr_angle__coeff_81",
    "loan__fft_coefficient__attr_angle__coeff_82",
    "loan__fft_coefficient__attr_angle__coeff_83",
    "loan__fft_coefficient__attr_angle__coeff_84",
    "loan__fft_coefficient__attr_angle__coeff_85",
    "loan__fft_coefficient__attr_angle__coeff_86",
    "loan__fft_coefficient__attr_angle__coeff_87",
    "loan__fft_coefficient__attr_angle__coeff_88",
    "loan__fft_coefficient__attr_angle__coeff_89",
    "loan__fft_coefficient__attr_angle__coeff_90",
    "loan__fft_coefficient__attr_angle__coeff_91",
    "loan__fft_coefficient__attr_angle__coeff_92",
    "loan__fft_coefficient__attr_angle__coeff_93",
    "loan__fft_coefficient__attr_angle__coeff_94",
    "loan__fft_coefficient__attr_angle__coeff_95",
    "loan__fft_coefficient__attr_angle__coeff_96",
    "loan__fft_coefficient__attr_angle__coeff_97",
    "loan__fft_coefficient__attr_angle__coeff_98",
    "loan__fft_coefficient__attr_angle__coeff_99",
]
df_fft_angle_set = load_data(name, features_to_drop)
# Out:
# Shape of mixed_1_set before droipping (400000, 44)
# Shape of mixed_1_set after droipping (400000, 41)
# Shape of symmetry_large_std_quantile_set before droipping (400000, 47)
# Shape of symmetry_large_std_quantile_set after droipping (400000, 11)
# Shape of acf_pacf_set before droipping (400000, 23)
# Shape of acf_pacf_set after droipping (400000, 22)
# Shape of cwt_coeff_set before droipping (400000, 60)
# Shape of cwt_coeff_set after droipping (400000, 60)
# Shape of change_quantile_set before droipping (400000, 60)
# Shape of change_quantile_set after droipping (400000, 60)
# Shape of liner_agg_linear_set before droipping (400000, 53)
# Shape of liner_agg_linear_set after droipping (400000, 49)
# Shape of mixed_2_set before droipping (400000, 24)
# Shape of mixed_2_set after droipping (400000, 16)
# Shape of mixed_3_set before droipping (400000, 30)
# Shape of mixed_3_set after droipping (400000, 30)
# Shape of mixed_4_set before droipping (400000, 42)
# Shape of mixed_4_set after droipping (400000, 34)
# Shape of fft_real_set before droipping (400000, 100)
# Shape of fft_real_set after droipping (400000, 51)
# Shape of fft_imag_set before droipping (400000, 100)
# Shape of fft_imag_set after droipping (400000, 49)
# Shape of fft_abs_set before droipping (400000, 100)
# Shape of fft_abs_set after droipping (400000, 51)
# Shape of fft_angle_set before droipping (400000, 100)
# Shape of fft_angle_set after droipping (400000, 50)

# %%
dfs= [df_acf_pacf_set, df_change_quantile_set, df_cwt_coeff_set, df_fft_abs_set, df_fft_angle_set, df_fft_imag_set, df_fft_real_set, df_liner_agg_linear_set, df_mixed_1_set, df_mixed_2_set, df_mixed_3_set, df_mixed_4_set, df_sym]

result_df = pd.concat(dfs, axis=1)

# %%
result_df.to_parquet(f"{constants.FEATURES_DATA_DIR}/cast/tsfresh_f_merged.parquet", index=True)

# %%
features_df = pd.read_parquet(f"{constants.FEATURES_DATA_DIR}/cast/tsfresh_f_merged.parquet")

# %%
train_df, test_df, sample_submission_df = process_data.read_processed_data(
    logger,
    constants.PROCESSED_DATA_DIR,
    train=True,
    test=True,
    sample_submission=True,
)

# %%
len(train_df)
# Out:
# 250000

# %%
train_df_f = features_df.iloc[0: len(train_df)]

# %%
train_df_f["loss"] = train_df.loss
# Out:
# <ipython-input-28-4155d3197f24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_f["loss"] = train_df.loss

# %%
c = train_df_f.corr()

# %%
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
c["loss"].sort_values(ascending=False)
# Out:
# loss                                                                1.000
# loan__fft_coefficient__attr_imag__coeff_21                          0.025
# loan__fft_coefficient__attr_real__coeff_13                          0.021
# loan__fft_coefficient__attr_real__coeff_37                          0.020
# loan__fft_coefficient__attr_imag__coeff_37                          0.020
# loan__fft_coefficient__attr_real__coeff_31                          0.019
# loan__fft_coefficient__attr_real__coeff_46                          0.018
# loan__fft_coefficient__attr_imag__coeff_43                          0.017
# loan__fft_coefficient__attr_angle__coeff_21                         0.017
# loan__cwt_coefficients__coeff_0__w_2__widths_251020                 0.016
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_7      0.016
# loan__cwt_coefficients__coeff_14__w_5__widths_251020                0.015
# loan__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_min      0.015
# loan__fft_coefficient__attr_real__coeff_17                          0.015
# loan__fft_coefficient__attr_real__coeff_22                          0.015
# loan__fft_coefficient__attr_imag__coeff_10                          0.015
# loan__autocorrelation__lag_2                                        0.015
# loan__fft_coefficient__attr_imag__coeff_45                          0.015
# loan__partial_autocorrelation__lag_2                                0.015
# loan__fft_coefficient__attr_real__coeff_6                           0.015
# loan__fft_coefficient__attr_imag__coeff_6                           0.014
# loan__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_min     0.014
# loan__cwt_coefficients__coeff_14__w_20__widths_251020               0.014
# loan__cwt_coefficients__coeff_7__w_2__widths_251020                 0.013
# loan__cwt_coefficients__coeff_1__w_2__widths_251020                 0.013
# loan__fft_coefficient__attr_imag__coeff_35                          0.013
# loan__agg_linear_trend__attr_intercept__chunk_len_50__f_agg_mean    0.013
# loan__cwt_coefficients__coeff_13__w_5__widths_251020                0.013
# loan__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_mean    0.013
# loan__cwt_coefficients__coeff_13__w_20__widths_251020               0.013
# loan__fft_coefficient__attr_real__coeff_7                           0.013
# loan__fft_coefficient__attr_abs__coeff_43                           0.012
# loan__cwt_coefficients__coeff_12__w_20__widths_251020               0.012
# loan__fft_coefficient__attr_real__coeff_50                          0.012
# loan__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_mean     0.012
# loan__fft_coefficient__attr_imag__coeff_14                          0.012
# loan__quantile__q_0.8                                               0.012
# loan__linear_trend__attr_intercept                                  0.012
# loan__fft_coefficient__attr_abs__coeff_6                            0.012
# loan__c3__lag_1                                                     0.012
# loan__fft_coefficient__attr_imag__coeff_47                          0.012
# loan__c3__lag_2                                                     0.012
# loan__fft_coefficient__attr_angle__coeff_45                         0.012
# loan__cwt_coefficients__coeff_11__w_20__widths_251020               0.012
# loan__fft_coefficient__attr_real__coeff_20                          0.011
# loan__fft_coefficient__attr_imag__coeff_9                           0.011
# loan__cwt_coefficients__coeff_10__w_20__widths_251020               0.011
# loan__fft_coefficient__attr_abs__coeff_42                           0.011
# loan__fft_coefficient__attr_abs__coeff_37                           0.011
# loan__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_mean        0.011
# loan__cwt_coefficients__coeff_9__w_20__widths_251020                0.011
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_1      0.011
# loan__fft_coefficient__attr_abs__coeff_9                            0.011
# loan__fft_coefficient__attr_imag__coeff_15                          0.011
# loan__ratio_beyond_r_sigma__r_1                                     0.011
# loan__fft_coefficient__attr_angle__coeff_47                         0.010
# loan__ar_coefficient__coeff_5__k_10                                 0.010
# loan__sum_values                                                    0.010
# loan__mean                                                          0.010
# loan__fft_coefficient__attr_abs__coeff_0                            0.010
# loan__fft_coefficient__attr_real__coeff_0                           0.010
# loan__quantile__q_0.7                                               0.010
# loan__c3__lag_3                                                     0.010
# loan__cwt_coefficients__coeff_6__w_2__widths_251020                 0.010
# loan__quantile__q_0.6                                               0.010
# loan__cwt_coefficients__coeff_12__w_5__widths_251020                0.010
# loan__longest_strike_below_mean                                     0.010
# loan__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_min         0.010
# loan__fft_coefficient__attr_real__coeff_15                          0.010
# loan__cwt_coefficients__coeff_14__w_2__widths_251020                0.010
# loan__cwt_coefficients__coeff_8__w_20__widths_251020                0.009
# loan__agg_linear_trend__attr_slope__chunk_len_10__f_agg_var         0.009
# loan__fft_coefficient__attr_abs__coeff_3                            0.009
# loan__fft_coefficient__attr_angle__coeff_6                          0.009
# loan__fft_coefficient__attr_real__coeff_43                          0.009
# loan__abs_energy                                                    0.009
# loan__fft_coefficient__attr_imag__coeff_5                           0.009
# loan__agg_linear_trend__attr_slope__chunk_len_5__f_agg_var          0.009
# loan__root_mean_square                                              0.009
# loan__fft_coefficient__attr_abs__coeff_36                           0.009
# loan__fft_coefficient__attr_abs__coeff_15                           0.009
# loan__agg_linear_trend__attr_rvalue__chunk_len_10__f_agg_var        0.009
# loan__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_mean       0.009
# loan__cwt_coefficients__coeff_7__w_20__widths_251020                0.009
# loan__fft_coefficient__attr_angle__coeff_43                         0.009
# loan__fft_coefficient__attr_real__coeff_39                          0.009
# loan__fft_coefficient__attr_angle__coeff_14                         0.009
# loan__ar_coefficient__coeff_2__k_10                                 0.009
# loan__fft_coefficient__attr_real__coeff_11                          0.009
# loan__agg_linear_trend__attr_rvalue__chunk_len_5__f_agg_var         0.009
# loan__cwt_coefficients__coeff_8__w_2__widths_251020                 0.009
# loan__fft_coefficient__attr_angle__coeff_31                         0.009
# loan__fft_coefficient__attr_real__coeff_19                          0.008
# loan__fft_coefficient__attr_imag__coeff_49                          0.008
# loan__agg_linear_trend__attr_slope__chunk_len_50__f_agg_var         0.008
# loan__fft_coefficient__attr_imag__coeff_20                          0.008
# loan__cwt_coefficients__coeff_6__w_20__widths_251020                0.008
# loan__fft_coefficient__attr_abs__coeff_19                           0.008
# loan__fft_coefficient__attr_angle__coeff_10                         0.008
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_3      0.008
# loan__fft_coefficient__attr_angle__coeff_13                         0.008
# loan__fft_coefficient__attr_angle__coeff_35                         0.008
# loan__fft_coefficient__attr_abs__coeff_5                            0.008
# loan__fft_coefficient__attr_angle__coeff_49                         0.008
# loan__fft_coefficient__attr_abs__coeff_10                           0.007
# loan__fft_coefficient__attr_angle__coeff_5                          0.007
# loan__fft_coefficient__attr_imag__coeff_41                          0.007
# loan__fft_coefficient__attr_abs__coeff_35                           0.007
# loan__friedrich_coefficients__coeff_2__m_3__r_30                    0.007
# loan__cwt_coefficients__coeff_5__w_20__widths_251020                0.007
# loan__quantile__q_0.1                                               0.007
# loan__cwt_coefficients__coeff_3__w_20__widths_251020                0.007
# loan__spkt_welch_density__coeff_2                                   0.007
# loan__cwt_coefficients__coeff_11__w_10__widths_251020               0.007
# loan__cwt_coefficients__coeff_4__w_20__widths_251020                0.007
# loan__cwt_coefficients__coeff_12__w_10__widths_251020               0.007
# loan__cwt_coefficients__coeff_11__w_5__widths_251020                0.007
# loan__fft_coefficient__attr_imag__coeff_39                          0.007
# loan__cwt_coefficients__coeff_10__w_10__widths_251020               0.007
# loan__spkt_welch_density__coeff_8                                   0.007
# loan__fft_coefficient__attr_angle__coeff_9                          0.007
# loan__cwt_coefficients__coeff_13__w_2__widths_251020                0.007
# loan__cwt_coefficients__coeff_13__w_10__widths_251020               0.007
# loan__fft_coefficient__attr_imag__coeff_13                          0.006
# loan__fft_coefficient__attr_abs__coeff_24                           0.006
# loan__augmented_dickey_fuller__attr_teststat__autolag_AIC           0.006
# loan__fft_coefficient__attr_angle__coeff_20                         0.006
# loan__fft_coefficient__attr_real__coeff_18                          0.006
# loan__quantile__q_0.4                                               0.006
# loan__fft_coefficient__attr_real__coeff_1                           0.006
# loan__cwt_coefficients__coeff_9__w_10__widths_251020                0.006
# loan__ratio_beyond_r_sigma__r_05                                    0.006
# loan__number_peaks__n_10                                            0.006
# loan__fft_coefficient__attr_real__coeff_4                           0.006
# loan__fft_coefficient__attr_real__coeff_10                          0.006
# loan__cwt_coefficients__coeff_14__w_10__widths_251020               0.006
# loan__fft_coefficient__attr_angle__coeff_39                         0.006
# loan__median                                                        0.006
# loan__fft_coefficient__attr_real__coeff_14                          0.006
# loan__fft_coefficient__attr_imag__coeff_28                          0.006
# loan__friedrich_coefficients__coeff_0__m_3__r_30                    0.006
# loan__fft_coefficient__attr_imag__coeff_12                          0.006
# loan__fft_coefficient__attr_imag__coeff_40                          0.006
# loan__fft_coefficient__attr_imag__coeff_31                          0.006
# loan__spkt_welch_density__coeff_5                                   0.006
# loan__partial_autocorrelation__lag_5                                0.006
# loan__cwt_coefficients__coeff_8__w_10__widths_251020                0.006
# loan__lempel_ziv_complexity__bins_3                                 0.006
# loan__change_quantiles__f_agg_mean__isabs_True__qh_10__ql_02        0.005
# loan__quantile__q_0.3                                               0.005
# loan__quantile__q_0.9                                               0.005
# loan__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_min        0.005
# loan__fft_coefficient__attr_real__coeff_23                          0.005
# loan__quantile__q_0.2                                               0.005
# loan__autocorrelation__lag_3                                        0.005
# loan__ar_coefficient__coeff_1__k_10                                 0.005
# loan__partial_autocorrelation__lag_3                                0.005
# loan__change_quantiles__f_agg_var__isabs_False__qh_10__ql_02        0.005
# loan__augmented_dickey_fuller__attr_usedlag__autolag_AIC            0.005
# loan__fft_coefficient__attr_angle__coeff_28                         0.005
# loan__cwt_coefficients__coeff_2__w_20__widths_251020                0.005
# loan__cwt_coefficients__coeff_7__w_10__widths_251020                0.005
# loan__agg_linear_trend__attr_intercept__chunk_len_50__f_agg_min     0.005
# loan__cwt_coefficients__coeff_1__w_20__widths_251020                0.005
# loan__agg_linear_trend__attr_rvalue__chunk_len_50__f_agg_var        0.005
# loan__fft_coefficient__attr_angle__coeff_41                         0.005
# loan__autocorrelation__lag_5                                        0.004
# loan__change_quantiles__f_agg_var__isabs_True__qh_08__ql_04         0.004
# loan__minimum                                                       0.004
# loan__fft_coefficient__attr_real__coeff_32                          0.004
# loan__fft_coefficient__attr_abs__coeff_2                            0.004
# loan__ar_coefficient__coeff_3__k_10                                 0.004
# loan__fft_coefficient__attr_abs__coeff_30                           0.004
# loan__cwt_coefficients__coeff_6__w_10__widths_251020                0.004
# loan__fft_coefficient__attr_abs__coeff_41                           0.004
# loan__fft_coefficient__attr_angle__coeff_17                         0.004
# loan__cwt_coefficients__coeff_0__w_20__widths_251020                0.004
# loan__change_quantiles__f_agg_var__isabs_False__qh_08__ql_06        0.004
# loan__ar_coefficient__coeff_9__k_10                                 0.004
# loan__cwt_coefficients__coeff_10__w_5__widths_251020                0.004
# loan__approximate_entropy__m_2__r_07                                0.003
# loan__last_location_of_minimum                                      0.003
# loan__first_location_of_minimum                                     0.003
# loan__agg_linear_trend__attr_slope__chunk_len_50__f_agg_max         0.003
# loan__change_quantiles__f_agg_var__isabs_False__qh_04__ql_00        0.003
# loan__fft_coefficient__attr_abs__coeff_8                            0.003
# loan__fft_coefficient__attr_abs__coeff_11                           0.003
# loan__fft_coefficient__attr_abs__coeff_39                           0.003
# loan__autocorrelation__lag_1                                        0.003
# loan__partial_autocorrelation__lag_1                                0.003
# loan__mean_second_derivative_central                                0.003
# loan__fft_coefficient__attr_imag__coeff_38                          0.003
# loan__fft_coefficient__attr_real__coeff_8                           0.003
# loan__longest_strike_above_mean                                     0.003
# loan__cwt_coefficients__coeff_5__w_10__widths_251020                0.003
# loan__change_quantiles__f_agg_var__isabs_True__qh_10__ql_02         0.003
# loan__change_quantiles__f_agg_mean__isabs_True__qh_04__ql_00        0.003
# loan__change_quantiles__f_agg_var__isabs_True__qh_08__ql_02         0.003
# loan__number_crossing_m__m_1                                        0.003
# loan__approximate_entropy__m_2__r_09                                0.003
# loan__number_cwt_peaks__n_1                                         0.003
# loan__partial_autocorrelation__lag_7                                0.003
# loan__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_var        0.003
# loan__change_quantiles__f_agg_var__isabs_True__qh_02__ql_00         0.003
# loan__fft_coefficient__attr_real__coeff_25                          0.003
# loan__number_peaks__n_1                                             0.003
# loan__lempel_ziv_complexity__bins_5                                 0.003
# loan__has_duplicate_max                                             0.003
# loan__fft_coefficient__attr_angle__coeff_40                         0.003
# loan__fft_coefficient__attr_real__coeff_26                          0.003
# loan__change_quantiles__f_agg_mean__isabs_False__qh_08__ql_04       0.002
# loan__agg_autocorrelation__f_agg_mean__maxlag_40                    0.002
# loan__lempel_ziv_complexity__bins_10                                0.002
# loan__approximate_entropy__m_2__r_03                                0.002
# loan__agg_linear_trend__attr_rvalue__chunk_len_5__f_agg_max         0.002
# loan__change_quantiles__f_agg_var__isabs_True__qh_08__ql_06         0.002
# loan__lempel_ziv_complexity__bins_100                               0.002
# loan__change_quantiles__f_agg_var__isabs_False__qh_08__ql_04        0.002
# loan__agg_linear_trend__attr_slope__chunk_len_5__f_agg_max          0.002
# loan__fft_coefficient__attr_real__coeff_45                          0.002
# loan__fft_coefficient__attr_imag__coeff_44                          0.002
# loan__fft_coefficient__attr_real__coeff_34                          0.002
# loan__change_quantiles__f_agg_mean__isabs_True__qh_08__ql_06        0.002
# loan__range_count__max_1__min_minus1                                0.002
# loan__agg_linear_trend__attr_slope__chunk_len_10__f_agg_max         0.002
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_8      0.002
# loan__cwt_coefficients__coeff_4__w_10__widths_251020                0.002
# loan__binned_entropy__max_bins_10                                   0.002
# loan__change_quantiles__f_agg_var__isabs_True__qh_04__ql_00         0.002
# loan__ar_coefficient__coeff_7__k_10                                 0.002
# loan__approximate_entropy__m_2__r_05                                0.002
# loan__partial_autocorrelation__lag_9                                0.002
# loan__fft_coefficient__attr_angle__coeff_37                         0.002
# loan__autocorrelation__lag_7                                        0.002
# loan__index_mass_quantile__q_0.7                                    0.002
# loan__time_reversal_asymmetry_statistic__lag_3                      0.002
# loan__change_quantiles__f_agg_var__isabs_False__qh_02__ql_00        0.002
# loan__change_quantiles__f_agg_var__isabs_False__qh_08__ql_02        0.002
# loan__agg_linear_trend__attr_rvalue__chunk_len_50__f_agg_max        0.001
# loan__fft_coefficient__attr_angle__coeff_12                         0.001
# loan__agg_linear_trend__attr_rvalue__chunk_len_10__f_agg_max        0.001
# loan__fft_coefficient__attr_real__coeff_49                          0.001
# loan__fft_coefficient__attr_abs__coeff_16                           0.001
# loan__autocorrelation__lag_9                                        0.001
# loan__last_location_of_maximum                                      0.001
# loan__first_location_of_maximum                                     0.001
# loan__variance                                                      0.001
# loan__percentage_of_reoccurring_datapoints_to_all_datapoints        0.001
# loan__has_duplicate                                                 0.001
# loan__percentage_of_reoccurring_values_to_all_values                0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_04__ql_02        0.001
# loan__sum_of_reoccurring_data_points                                0.001
# loan__sum_of_reoccurring_values                                     0.001
# loan__standard_deviation                                            0.001
# loan__fft_coefficient__attr_imag__coeff_18                          0.001
# loan__change_quantiles__f_agg_mean__isabs_False__qh_02__ql_00       0.001
# loan__augmented_dickey_fuller__attr_pvalue__autolag_AIC             0.001
# loan__cwt_coefficients__coeff_3__w_10__widths_251020                0.001
# loan__maximum                                                       0.001
# loan__linear_trend__attr_stderr                                     0.001
# loan__fft_coefficient__attr_abs__coeff_46                           0.001
# loan__change_quantiles__f_agg_var__isabs_True__qh_08__ql_00         0.001
# loan__agg_autocorrelation__f_agg_median__maxlag_40                  0.001
# loan__cwt_coefficients__coeff_0__w_5__widths_251020                 0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_08__ql_04        0.001
# loan__change_quantiles__f_agg_var__isabs_False__qh_06__ql_04        0.001
# loan__change_quantiles__f_agg_mean__isabs_False__qh_08__ql_06       0.000
# loan__change_quantiles__f_agg_mean__isabs_True__qh_08__ql_02        0.000
# loan__fft_coefficient__attr_angle__coeff_18                         0.000
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_0      0.000
# loan__count_below_mean                                              0.000
# loan__change_quantiles__f_agg_mean__isabs_True__qh_02__ql_00        0.000
# loan__permutation_entropy__dimension_3__tau_1                       0.000
# loan__fft_coefficient__attr_angle__coeff_15                         0.000
# loan__change_quantiles__f_agg_mean__isabs_True__qh_10__ql_04        0.000
# loan__fft_coefficient__attr_imag__coeff_2                           0.000
# loan__change_quantiles__f_agg_var__isabs_False__qh_04__ql_02        0.000
# loan__fft_coefficient__attr_real__coeff_16                          0.000
# loan__fft_coefficient__attr_abs__coeff_49                           0.000
# loan__cwt_coefficients__coeff_9__w_5__widths_251020                 0.000
# loan__fft_coefficient__attr_angle__coeff_38                         0.000
# loan__cwt_coefficients__coeff_2__w_10__widths_251020                0.000
# loan__change_quantiles__f_agg_mean__isabs_False__qh_06__ql_02       0.000
# loan__fft_coefficient__attr_angle__coeff_2                          0.000
# loan__fft_coefficient__attr_abs__coeff_40                          -0.000
# loan__change_quantiles__f_agg_var__isabs_False__qh_08__ql_00       -0.000
# loan__lempel_ziv_complexity__bins_2                                -0.000
# loan__permutation_entropy__dimension_6__tau_1                      -0.000
# loan__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_max     -0.000
# loan__fft_coefficient__attr_angle__coeff_48                        -0.000
# loan__change_quantiles__f_agg_mean__isabs_False__qh_04__ql_00      -0.000
# loan__change_quantiles__f_agg_var__isabs_True__qh_04__ql_02        -0.000
# loan__absolute_sum_of_changes                                      -0.000
# loan__change_quantiles__f_agg_mean__isabs_True__qh_10__ql_00       -0.000
# loan__mean_abs_change                                              -0.000
# loan__fft_coefficient__attr_abs__coeff_26                          -0.000
# loan__ar_coefficient__coeff_10__k_10                               -0.000
# loan__count_above_mean                                             -0.000
# loan__fft_coefficient__attr_real__coeff_42                         -0.000
# loan__change_quantiles__f_agg_var__isabs_False__qh_06__ql_00       -0.000
# loan__change_quantiles__f_agg_var__isabs_True__qh_06__ql_04        -0.001
# loan__fft_coefficient__attr_imag__coeff_17                         -0.001
# loan__agg_linear_trend__attr_stderr__chunk_len_10__f_agg_max       -0.001
# loan__permutation_entropy__dimension_4__tau_1                      -0.001
# loan__change_quantiles__f_agg_var__isabs_False__qh_10__ql_04       -0.001
# loan__ratio_beyond_r_sigma__r_3                                    -0.001
# loan__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_max    -0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_06__ql_00       -0.001
# loan__fft_coefficient__attr_angle__coeff_32                        -0.001
# loan__agg_linear_trend__attr_slope__chunk_len_50__f_agg_min        -0.001
# loan__agg_autocorrelation__f_agg_var__maxlag_40                    -0.001
# loan__cwt_coefficients__coeff_1__w_10__widths_251020               -0.001
# loan__fft_coefficient__attr_real__coeff_28                         -0.001
# loan__agg_linear_trend__attr_intercept__chunk_len_50__f_agg_max    -0.001
# loan__fft_coefficient__attr_abs__coeff_29                          -0.001
# loan__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_var        -0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_08__ql_00       -0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_06__ql_02       -0.001
# loan__fft_coefficient__attr_real__coeff_47                         -0.001
# loan__change_quantiles__f_agg_var__isabs_False__qh_06__ql_02       -0.001
# loan__cwt_coefficients__coeff_1__w_5__widths_251020                -0.001
# loan__benford_correlation                                          -0.001
# loan__change_quantiles__f_agg_var__isabs_True__qh_06__ql_00        -0.001
# loan__change_quantiles__f_agg_var__isabs_True__qh_06__ql_02        -0.001
# loan__fft_coefficient__attr_imag__coeff_24                         -0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_06__ql_04       -0.001
# loan__fft_coefficient__attr_abs__coeff_25                          -0.001
# loan__ratio_value_number_to_time_series_length                     -0.001
# loan__change_quantiles__f_agg_mean__isabs_True__qh_10__ql_06       -0.001
# loan__fft_coefficient__attr_angle__coeff_24                        -0.001
# loan__fft_coefficient__attr_imag__coeff_48                         -0.001
# loan__agg_linear_trend__attr_stderr__chunk_len_5__f_agg_max        -0.001
# loan__agg_linear_trend__attr_rvalue__chunk_len_50__f_agg_min       -0.001
# loan__change_quantiles__f_agg_mean__isabs_False__qh_04__ql_02      -0.001
# loan__max_langevin_fixed_point__m_3__r_30                          -0.001
# loan__permutation_entropy__dimension_7__tau_1                      -0.001
# loan__large_standard_deviation__r_0.25                             -0.001
# loan__fft_coefficient__attr_abs__coeff_28                          -0.001
# loan__cid_ce__normalize_False                                      -0.002
# loan__fft_coefficient__attr_real__coeff_3                          -0.002
# loan__change_quantiles__f_agg_var__isabs_False__qh_10__ql_00       -0.002
# loan__permutation_entropy__dimension_5__tau_1                      -0.002
# loan__change_quantiles__f_agg_var__isabs_True__qh_10__ql_08        -0.002
# loan__fft_coefficient__attr_abs__coeff_44                          -0.002
# loan__approximate_entropy__m_2__r_01                               -0.002
# loan__fft_coefficient__attr_angle__coeff_16                        -0.002
# loan__cwt_coefficients__coeff_0__w_10__widths_251020               -0.002
# loan__change_quantiles__f_agg_mean__isabs_True__qh_10__ql_08       -0.002
# loan__cwt_coefficients__coeff_12__w_2__widths_251020               -0.002
# loan__fft_coefficient__attr_abs__coeff_32                          -0.002
# loan__fft_coefficient__attr_imag__coeff_22                         -0.002
# loan__fourier_entropy__bins_3                                      -0.002
# loan__ar_coefficient__coeff_8__k_10                                -0.002
# loan__symmetry_looking__r_0.05                                     -0.002
# loan__number_cwt_peaks__n_5                                        -0.002
# loan__change_quantiles__f_agg_mean__isabs_False__qh_06__ql_04      -0.002
# loan__cwt_coefficients__coeff_9__w_2__widths_251020                -0.002
# loan__large_standard_deviation__r_0.2                              -0.002
# loan__autocorrelation__lag_0                                       -0.002
# loan__fourier_entropy__bins_5                                      -0.002
# loan__linear_trend__attr_pvalue                                    -0.002
# loan__fft_coefficient__attr_abs__coeff_21                          -0.002
# loan__change_quantiles__f_agg_mean__isabs_False__qh_06__ql_00      -0.002
# loan__partial_autocorrelation__lag_8                               -0.003
# loan__change_quantiles__f_agg_var__isabs_False__qh_10__ql_06       -0.003
# loan__number_crossing_m__m_0                                       -0.003
# loan__ratio_beyond_r_sigma__r_25                                   -0.003
# loan__number_peaks__n_5                                            -0.003
# loan__change_quantiles__f_agg_mean__isabs_False__qh_10__ql_08      -0.003
# loan__fft_coefficient__attr_abs__coeff_12                          -0.003
# loan__autocorrelation__lag_8                                       -0.003
# loan__fft_coefficient__attr_real__coeff_30                         -0.003
# loan__value_count__value_0                                         -0.003
# loan__count_below__t_0                                             -0.003
# loan__change_quantiles__f_agg_var__isabs_True__qh_10__ql_04        -0.003
# loan__fft_coefficient__attr_angle__coeff_1                         -0.003
# loan__index_mass_quantile__q_0.1                                   -0.003
# loan__fourier_entropy__bins_2                                      -0.003
# loan__fft_coefficient__attr_angle__coeff_11                        -0.003
# loan__cwt_coefficients__coeff_2__w_5__widths_251020                -0.003
# loan__fft_coefficient__attr_abs__coeff_50                          -0.003
# loan__fft_coefficient__attr_imag__coeff_33                         -0.003
# loan__fft_coefficient__attr_imag__coeff_16                         -0.003
# loan__cwt_coefficients__coeff_8__w_5__widths_251020                -0.003
# loan__fft_coefficient__attr_abs__coeff_1                           -0.003
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_2     -0.003
# loan__fft_coefficient__attr_abs__coeff_48                          -0.003
# loan__fft_coefficient__attr_abs__coeff_22                          -0.003
# loan__value_count__value_1                                         -0.003
# loan__cwt_coefficients__coeff_2__w_2__widths_251020                -0.003
# loan__change_quantiles__f_agg_var__isabs_True__qh_10__ql_00        -0.003
# loan__fft_coefficient__attr_abs__coeff_18                          -0.003
# loan__fft_coefficient__attr_real__coeff_24                         -0.003
# loan__fourier_entropy__bins_10                                     -0.003
# loan__fft_coefficient__attr_angle__coeff_33                        -0.003
# loan__fft_coefficient__attr_real__coeff_41                         -0.003
# loan__change_quantiles__f_agg_mean__isabs_False__qh_08__ql_02      -0.004
# loan__cid_ce__normalize_True                                       -0.004
# loan__ar_coefficient__coeff_0__k_10                                -0.004
# loan__change_quantiles__f_agg_var__isabs_False__qh_10__ql_08       -0.004
# loan__fft_coefficient__attr_abs__coeff_34                          -0.004
# loan__mean_change                                                  -0.004
# loan__change_quantiles__f_agg_mean__isabs_False__qh_10__ql_00      -0.004
# loan__change_quantiles__f_agg_mean__isabs_False__qh_10__ql_02      -0.004
# loan__fourier_entropy__bins_100                                    -0.004
# loan__fft_coefficient__attr_angle__coeff_22                        -0.004
# loan__agg_linear_trend__attr_intercept__chunk_len_50__f_agg_var    -0.004
# loan__index_mass_quantile__q_0.6                                   -0.004
# loan__cwt_coefficients__coeff_3__w_5__widths_251020                -0.005
# loan__fft_coefficient__attr_abs__coeff_4                           -0.005
# loan__fft_coefficient__attr_real__coeff_12                         -0.005
# loan__fft_coefficient__attr_angle__coeff_42                        -0.005
# loan__partial_autocorrelation__lag_6                               -0.005
# loan__fft_coefficient__attr_abs__coeff_23                          -0.005
# loan__change_quantiles__f_agg_var__isabs_True__qh_10__ql_06        -0.005
# loan__fft_coefficient__attr_abs__coeff_47                          -0.005
# loan__fft_coefficient__attr_imag__coeff_32                         -0.005
# loan__skewness                                                     -0.005
# loan__cwt_coefficients__coeff_5__w_2__widths_251020                -0.005
# loan__ar_coefficient__coeff_6__k_10                                -0.005
# loan__time_reversal_asymmetry_statistic__lag_2                     -0.005
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_5     -0.006
# loan__cwt_coefficients__coeff_7__w_5__widths_251020                -0.006
# loan__index_mass_quantile__q_0.8                                   -0.006
# loan__fft_coefficient__attr_abs__coeff_17                          -0.006
# loan__fft_coefficient__attr_imag__coeff_1                          -0.006
# loan__fft_coefficient__attr_abs__coeff_33                          -0.006
# loan__autocorrelation__lag_6                                       -0.006
# loan__fft_coefficient__attr_imag__coeff_11                         -0.006
# loan__cwt_coefficients__coeff_4__w_5__widths_251020                -0.006
# loan__ratio_beyond_r_sigma__r_2                                    -0.006
# loan__fft_coefficient__attr_abs__coeff_13                          -0.006
# loan__fft_coefficient__attr_angle__coeff_44                        -0.006
# loan__fft_coefficient__attr_angle__coeff_8                         -0.006
# loan__fft_coefficient__attr_angle__coeff_27                        -0.006
# loan__fft_coefficient__attr_abs__coeff_38                          -0.006
# loan__friedrich_coefficients__coeff_3__m_3__r_30                   -0.006
# loan__friedrich_coefficients__coeff_1__m_3__r_30                   -0.006
# loan__variation_coefficient                                        -0.007
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_4     -0.007
# loan__change_quantiles__f_agg_mean__isabs_False__qh_10__ql_06      -0.007
# loan__cwt_coefficients__coeff_6__w_5__widths_251020                -0.007
# loan__cwt_coefficients__coeff_5__w_5__widths_251020                -0.007
# loan__fft_coefficient__attr_real__coeff_36                         -0.007
# loan__fft_coefficient__attr_imag__coeff_7                          -0.007
# loan__fft_coefficient__attr_abs__coeff_31                          -0.007
# loan__agg_linear_trend__attr_rvalue__chunk_len_50__f_agg_mean      -0.007
# loan__fft_coefficient__attr_abs__coeff_7                           -0.007
# loan__kurtosis                                                     -0.007
# loan__fft_coefficient__attr_angle__coeff_25                        -0.007
# loan__fft_coefficient__attr_angle__coeff_34                        -0.007
# loan__ratio_beyond_r_sigma__r_15                                   -0.008
# loan__change_quantiles__f_agg_mean__isabs_False__qh_08__ql_00      -0.008
# loan__fft_coefficient__attr_abs__coeff_45                          -0.008
# loan__fft_coefficient__attr_imag__coeff_8                          -0.008
# loan__fft_coefficient__attr_real__coeff_9                          -0.008
# loan__agg_linear_trend__attr_rvalue__chunk_len_5__f_agg_mean       -0.008
# loan__index_mass_quantile__q_0.3                                   -0.008
# loan__agg_linear_trend__attr_rvalue__chunk_len_10__f_agg_mean      -0.008
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_9     -0.008
# loan__fft_coefficient__attr_real__coeff_40                         -0.008
# loan__linear_trend__attr_slope                                     -0.008
# loan__agg_linear_trend__attr_intercept__chunk_len_10__f_agg_var    -0.008
# loan__linear_trend__attr_rvalue                                    -0.008
# loan__fft_coefficient__attr_angle__coeff_29                        -0.009
# loan__fft_coefficient__attr_angle__coeff_4                         -0.009
# loan__fft_coefficient__attr_real__coeff_33                         -0.009
# loan__ar_coefficient__coeff_4__k_10                                -0.009
# loan__agg_linear_trend__attr_slope__chunk_len_5__f_agg_mean        -0.009
# loan__number_peaks__n_3                                            -0.009
# loan__fft_coefficient__attr_real__coeff_5                          -0.009
# loan__fft_coefficient__attr_angle__coeff_3                         -0.009
# loan__fft_coefficient__attr_real__coeff_38                         -0.009
# loan__fft_coefficient__attr_imag__coeff_23                         -0.009
# loan__fft_coefficient__attr_imag__coeff_25                         -0.009
# loan__agg_linear_trend__attr_slope__chunk_len_50__f_agg_mean       -0.009
# loan__agg_linear_trend__attr_slope__chunk_len_10__f_agg_mean       -0.009
# loan__fft_coefficient__attr_angle__coeff_30                        -0.010
# loan__agg_linear_trend__attr_intercept__chunk_len_5__f_agg_var     -0.010
# loan__change_quantiles__f_agg_mean__isabs_False__qh_10__ql_04      -0.010
# loan__agg_linear_trend__attr_slope__chunk_len_5__f_agg_min         -0.010
# loan__fft_coefficient__attr_angle__coeff_50                        -0.010
# loan__fft_coefficient__attr_angle__coeff_23                        -0.010
# loan__fft_coefficient__attr_real__coeff_35                         -0.010
# loan__fft_coefficient__attr_angle__coeff_26                        -0.010
# loan__agg_linear_trend__attr_rvalue__chunk_len_10__f_agg_min       -0.010
# loan__fft_coefficient__attr_angle__coeff_7                         -0.010
# loan__agg_linear_trend__attr_slope__chunk_len_10__f_agg_min        -0.010
# loan__fft_coefficient__attr_real__coeff_48                         -0.010
# loan__cwt_coefficients__coeff_11__w_2__widths_251020               -0.011
# loan__fft_coefficient__attr_abs__coeff_20                          -0.011
# loan__agg_linear_trend__attr_rvalue__chunk_len_5__f_agg_min        -0.011
# loan__fft_coefficient__attr_imag__coeff_30                         -0.011
# loan__index_mass_quantile__q_0.9                                   -0.011
# loan__fft_coefficient__attr_real__coeff_21                         -0.011
# loan__time_reversal_asymmetry_statistic__lag_1                     -0.011
# loan__index_mass_quantile__q_0.4                                   -0.011
# loan__fft_coefficient__attr_abs__coeff_14                          -0.011
# loan__fft_coefficient__attr_imag__coeff_4                          -0.012
# loan__cwt_coefficients__coeff_10__w_2__widths_251020               -0.012
# loan__fft_coefficient__attr_angle__coeff_19                        -0.012
# loan__energy_ratio_by_chunks__num_segments_10__segment_focus_6     -0.012
# loan__fft_coefficient__attr_imag__coeff_34                         -0.012
# loan__index_mass_quantile__q_0.2                                   -0.012
# loan__fft_coefficient__attr_real__coeff_2                          -0.012
# loan__fft_coefficient__attr_imag__coeff_46                         -0.012
# loan__fft_coefficient__attr_angle__coeff_36                        -0.012
# loan__fft_coefficient__attr_imag__coeff_29                         -0.012
# loan__fft_coefficient__attr_imag__coeff_42                         -0.013
# loan__fft_coefficient__attr_angle__coeff_46                        -0.013
# loan__partial_autocorrelation__lag_4                               -0.013
# loan__autocorrelation__lag_4                                       -0.013
# loan__fft_coefficient__attr_imag__coeff_26                         -0.013
# loan__fft_coefficient__attr_imag__coeff_3                          -0.014
# loan__fft_coefficient__attr_real__coeff_29                         -0.014
# loan__fft_coefficient__attr_real__coeff_44                         -0.014
# loan__fft_coefficient__attr_imag__coeff_36                         -0.017
# loan__cwt_coefficients__coeff_4__w_2__widths_251020                -0.018
# loan__cwt_coefficients__coeff_3__w_2__widths_251020                -0.020
# loan__fft_coefficient__attr_abs__coeff_27                          -0.021
# loan__fft_coefficient__attr_imag__coeff_27                         -0.021
# loan__fft_coefficient__attr_real__coeff_27                         -0.021
# loan__fft_coefficient__attr_imag__coeff_19                         -0.022
# loan__variance_larger_than_standard_deviation                         NaN
# loan__number_peaks__n_50                                              NaN
# Name: loss, dtype: float64
